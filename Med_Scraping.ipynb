# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
driver = webdriver.Chrome(executable_path = r"C:\Users\sheik\Downloads\chromedriver_win32\chromedriver.exe")
products=[] #List to store name of the product
prices=[] #List to store price of the product
quantity = []
company = []
types = []

def getphones(pages,labels):
    driver.get("https://www.1mg.com/drugs-all-medicines?page=pages&label="+labels)
    content = driver.page_source
    soup = BeautifulSoup(content)
    model = soup.find_all('div',{'class' : 'style__width-100p___2woP5 style__flex-row___m8FHw'})

    for a in model:
        name=(a.find('div', attrs = {'class' : 'style__font-bold___1k9Dl style__font-14px___YZZrf style__flex-row___2AKyf style__space-between___2mbvn style__padding-bottom-5px___2NrDR'}).findChildren()[0])
        price=(a.find('div', attrs = {'class' : 'style__font-bold___1k9Dl style__font-14px___YZZrf style__flex-row___2AKyf style__space-between___2mbvn style__padding-bottom-5px___2NrDR'}).findChildren()[1])
        quan = (a.find('div', attrs = {'class' : 'style__flex-column___1zNVy style__font-12px___2ru_e'}).findChildren()[0])
        comp = (a.find('div', attrs = {'class' : 'style__flex-column___1zNVy style__font-12px___2ru_e'}).findChildren()[1])
        typ = a.find('div', attrs = {'class' : 'style__font-12px___2ru_e style__product-content___5PFBW style__display-inline-block___2y7gd'})
        products.append(name.text)
        prices.append(price.text)
        quantity.append(quan.text)
        company.append(comp.text)
        types.append(typ.text)
    return

alpha = []
count = 97  



for i in range(26):
    alpha.append(chr(count))
    count = count+1
    
for i in range(26):
    for x in range(1,6): 
        getphones(x,alpha[i])
    
df = pd.DataFrame({'Product Name':products,'Price':prices,'Quantity':quantity,'Company':company, 'Type':types})

# %%
df
# Out:
#                          Product Name       Price                  Quantity  \
# 0     Ascoril D Plus Syrup Sugar Free     MRP₹118    bottle of 100 ml Syrup
# 1                Allegra 180mg Tablet  MRP₹217.48       strip of 10 tablets
# 2                Amoxyclav 625 Tablet  MRP₹113.25        strip of 6 tablets
# 3            Augmentin 625 Duo Tablet  MRP₹201.71       strip of 10 tablets
# 4                 Azithral 500 Tablet   MRP₹119.5        strip of 5 tablets
# ...                               ...         ...                       ...
# 3895               Zedocef 200 Tablet     MRP₹169       strip of 10 tablets
# 3896               Zenflox-UTI Tablet  MRP₹186.34       strip of 10 tablets
# 3897              Zocef-CV 500 Tablet     MRP₹519        strip of 6 tablets
# 3898              Zoryl-M 1 Tablet PR     MRP₹188     strip of 20 Tablet pr
# 3899           Zostum 1.5gm Injection   MRP₹376.2  vial of 1.5 gm Injection
#
#                                    Company  \
# 0             Glenmark Pharmaceuticals Ltd
# 1                        Sanofi India  Ltd
# 2                                   Abbott
# 3     Glaxo SmithKline Pharmaceuticals Ltd
# 4              Alembic Pharmaceuticals Ltd
# ...                                    ...
# 3895      Macleods Pharmaceuticals Pvt Ltd
# 3896                    Mankind Pharma Ltd
# 3897                Alkem Laboratories Ltd
# 3898             Intas Pharmaceuticals Ltd
# 3899               Zuventus Healthcare Ltd
#
#                                                    Type
# 0     Phenylephrine (5mg) + Chlorpheniramine Maleate...
# 1                                  Fexofenadine (180mg)
# 2       Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 3       Amoxycillin  (500mg) +  Clavulanic Acid (125mg)
# 4                                  Azithromycin (500mg)
# ...                                                 ...
# 3895                       Cefpodoxime Proxetil (200mg)
# 3896              Ofloxacin (200mg) + Flavoxate (200mg)
# 3897       Cefuroxime (500mg) + Clavulanic Acid (125mg)
# 3898              Glimepiride (1mg) + Metformin (500mg)
# 3899          Cefoperazone (1000mg) + Sulbactam (500mg)
#
# [3900 rows x 5 columns]

# %%
df
# Out:
# Empty DataFrame
# Columns: [Product Name, Price, Rating, Company, Type]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Product Name, Price, Rating, Company, Type]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Product Name, Price, Rating, Company, Type]
# Index: []

# %%
df
# Out:
# Empty DataFrame
# Columns: [Product Name, Price, Rating, Company, Type]
# Index: []

# %%
df
# Out:
#                               Product Name Price  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45   MRP
# 1           Banocide Forte TabletMRP₹43.62   MRP
# 2               Betnovate-N  CreamMRP₹36.6   MRP
# 3                    Benadryl SyrupMRP₹118   MRP
# 4         Bandy-Plus Chewable TabletMRP₹25   MRP
# ..                                     ...   ...
# 145        Betnesol Injection 1mlMRP₹37.44   MRP
# 146              Bactrim DS TabletMRP₹22.7   MRP
# 147                Bilashine TabletMRP₹118   MRP
# 148          Betnesol Forte TabletMRP₹21.3   MRP
# 149                Benxop Face WashMRP₹205   MRP
#
#                                     Rating  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45
# 1           Banocide Forte TabletMRP₹43.62
# 2               Betnovate-N  CreamMRP₹36.6
# 3                    Benadryl SyrupMRP₹118
# 4         Bandy-Plus Chewable TabletMRP₹25
# ..                                     ...
# 145        Betnesol Injection 1mlMRP₹37.44
# 146              Bactrim DS TabletMRP₹22.7
# 147                Bilashine TabletMRP₹118
# 148          Betnesol Forte TabletMRP₹21.3
# 149                Benxop Face WashMRP₹205
#
#                                    Company  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45
# 1           Banocide Forte TabletMRP₹43.62
# 2               Betnovate-N  CreamMRP₹36.6
# 3                    Benadryl SyrupMRP₹118
# 4         Bandy-Plus Chewable TabletMRP₹25
# ..                                     ...
# 145        Betnesol Injection 1mlMRP₹37.44
# 146              Bactrim DS TabletMRP₹22.7
# 147                Bilashine TabletMRP₹118
# 148          Betnesol Forte TabletMRP₹21.3
# 149                Benxop Face WashMRP₹205
#
#                                                   Type
# 0                                   Budesonide (0.5mg)
# 1                           Diethylcarbamazine (100mg)
# 2       Betamethasone (0.1% w/w) + Neomycin (0.5% w/w)
# 3    Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...
# 4             Ivermectin  (6mg) +  Albendazole (400mg)
# ..                                                 ...
# 145                             Betamethasone (4mg/ml)
# 146    Sulfamethoxazole (800mg) + Trimethoprim (160mg)
# 147                                   Bilastine (20mg)
# 148                                Betamethasone (1mg)
# 149                          Benzoyl Peroxide (4% w/w)
#
# [150 rows x 5 columns]

# %%
df
# Out:
#                               Product Name Price  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45   MRP
# 1           Banocide Forte TabletMRP₹43.62   MRP
# 2               Betnovate-N  CreamMRP₹36.6   MRP
# 3                    Benadryl SyrupMRP₹118   MRP
# 4         Bandy-Plus Chewable TabletMRP₹25   MRP
# ..                                     ...   ...
# 145        Betnesol Injection 1mlMRP₹37.44   MRP
# 146              Bactrim DS TabletMRP₹22.7   MRP
# 147                Bilashine TabletMRP₹118   MRP
# 148          Betnesol Forte TabletMRP₹21.3   MRP
# 149                Benxop Face WashMRP₹205   MRP
#
#                                     Rating  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45
# 1           Banocide Forte TabletMRP₹43.62
# 2               Betnovate-N  CreamMRP₹36.6
# 3                    Benadryl SyrupMRP₹118
# 4         Bandy-Plus Chewable TabletMRP₹25
# ..                                     ...
# 145        Betnesol Injection 1mlMRP₹37.44
# 146              Bactrim DS TabletMRP₹22.7
# 147                Bilashine TabletMRP₹118
# 148          Betnesol Forte TabletMRP₹21.3
# 149                Benxop Face WashMRP₹205
#
#                                    Company  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45
# 1           Banocide Forte TabletMRP₹43.62
# 2               Betnovate-N  CreamMRP₹36.6
# 3                    Benadryl SyrupMRP₹118
# 4         Bandy-Plus Chewable TabletMRP₹25
# ..                                     ...
# 145        Betnesol Injection 1mlMRP₹37.44
# 146              Bactrim DS TabletMRP₹22.7
# 147                Bilashine TabletMRP₹118
# 148          Betnesol Forte TabletMRP₹21.3
# 149                Benxop Face WashMRP₹205
#
#                                                   Type
# 0                                   Budesonide (0.5mg)
# 1                           Diethylcarbamazine (100mg)
# 2       Betamethasone (0.1% w/w) + Neomycin (0.5% w/w)
# 3    Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...
# 4             Ivermectin  (6mg) +  Albendazole (400mg)
# ..                                                 ...
# 145                             Betamethasone (4mg/ml)
# 146    Sulfamethoxazole (800mg) + Trimethoprim (160mg)
# 147                                   Bilastine (20mg)
# 148                                Betamethasone (1mg)
# 149                          Benzoyl Peroxide (4% w/w)
#
# [150 rows x 5 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#                               Product Name  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45
# 1           Banocide Forte TabletMRP₹43.62
# 2               Betnovate-N  CreamMRP₹36.6
# 3                    Benadryl SyrupMRP₹118
# 4         Bandy-Plus Chewable TabletMRP₹25
# ..                                     ...
# 145        Betnesol Injection 1mlMRP₹37.44
# 146              Bactrim DS TabletMRP₹22.7
# 147                Bilashine TabletMRP₹118
# 148          Betnesol Forte TabletMRP₹21.3
# 149                Benxop Face WashMRP₹205
#
#                                      Price  \
# 0    Budecort 0.5mg Respules 2mlMRP₹119.45
# 1           Banocide Forte TabletMRP₹43.62
# 2               Betnovate-N  CreamMRP₹36.6
# 3                    Benadryl SyrupMRP₹118
# 4         Bandy-Plus Chewable TabletMRP₹25
# ..                                     ...
# 145        Betnesol Injection 1mlMRP₹37.44
# 146              Bactrim DS TabletMRP₹22.7
# 147                Bilashine TabletMRP₹118
# 148          Betnesol Forte TabletMRP₹21.3
# 149                Benxop Face WashMRP₹205
#
#                                                 Rating  \
# 0                        packet of 5 respulesCipla Ltd
# 1    strip of 30 tabletsGlaxo SmithKline Pharmaceut...
# 2    tube of 20 gm CreamGlaxo SmithKline Pharmaceut...
# 3          bottle of 150 ml SyrupJohnson & Johnson Ltd
# 4         strip of 1 Chewable TabletMankind Pharma Ltd
# ..                                                 ...
# 145  packet of 8 injectionsGlaxo SmithKline Pharmac...
# 146                          strip of 10 tabletsAbbott
# 147  strip of 10 tabletsSun Pharmaceutical Industri...
# 148  strip of 20 tabletsGlaxo SmithKline Pharmaceut...
# 149  tube of 50 gm Face WashSalve Pharmaceuticals P...
#
#                                                Company  \
# 0                        packet of 5 respulesCipla Ltd
# 1    strip of 30 tabletsGlaxo SmithKline Pharmaceut...
# 2    tube of 20 gm CreamGlaxo SmithKline Pharmaceut...
# 3          bottle of 150 ml SyrupJohnson & Johnson Ltd
# 4         strip of 1 Chewable TabletMankind Pharma Ltd
# ..                                                 ...
# 145  packet of 8 injectionsGlaxo SmithKline Pharmac...
# 146                          strip of 10 tabletsAbbott
# 147  strip of 10 tabletsSun Pharmaceutical Industri...
# 148  strip of 20 tabletsGlaxo SmithKline Pharmaceut...
# 149  tube of 50 gm Face WashSalve Pharmaceuticals P...
#
#                                                   Type
# 0                                   Budesonide (0.5mg)
# 1                           Diethylcarbamazine (100mg)
# 2       Betamethasone (0.1% w/w) + Neomycin (0.5% w/w)
# 3    Diphenhydramine (14.08mg/5ml) + Ammonium Chlor...
# 4             Ivermectin  (6mg) +  Albendazole (400mg)
# ..                                                 ...
# 145                             Betamethasone (4mg/ml)
# 146    Sulfamethoxazole (800mg) + Trimethoprim (160mg)
# 147                                   Bilastine (20mg)
# 148                                Betamethasone (1mg)
# 149                          Benzoyl Peroxide (4% w/w)
#
# [150 rows x 5 columns]
